# %% [markdown]
# # **Herramientas de Análisis**
#
# ---
# ---
#
# <!-- script html for image -->
#
# <center>
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Sw-ep1-logo.svg/1280px-Sw-ep1-logo.svg.png"  width="500" height="150"/>
#
#
# <br>
#
# Fuente de la imagen: [https://es.wikipedia.org](https://es.wikipedia.org/wiki/Star_Wars:_Episodio_I_-_La_amenaza_fantasma)
#
# </center>
#
# <br>

# %% [markdown]
# # **Índice**
#
# ---
# ---
#
# > [Herramientas de Análisis](#scrollTo=yqTEtJSxSjoc&line=20&uniqifier=1)
# <br>
# >>
# >> [Preparación del Entorno](#scrollTo=8dbKvXOBMtBa&line=1&uniqifier=1) \\
# >>   \\
# >> [2 - Elementos Básicos de Python](#scrollTo=7ygQyWdBTi-t&line=1&uniqifier=1) \\
# >>
# >>> [2.1. Interfaz de Usuario](#scrollTo=-EuIBRfLSjoz) \\
# >>>
# >>> [2.2. Ficheros *.py](#scrollTo=1eV_DFf_SjpF) \\
# >>>
# >>> [2.3. Notebooks Jupyter (*.ipynb)](#scrollTo=XHAo_I8zSjpH) \\
# >>>
# >>>> [2.3.1. Colaboratory o Colab](#scrollTo=zrwhbzt5SjpI&line=1&uniqifier=1) \\
# >>>>
# >>>> [2.3.2. Actividad Guiada 2.1](#scrollTo=qDM543WISjpK&line=1&uniqifier=1) \\
# >>>>
# >>>> [2.3.3. Editar Notebooks Jupyter](#scrollTo=kKw_vgA4SjpM&line=3&uniqifier=1) \\
# >>>>
# >>>>> [2.3.3.1. Atajos de Teclado](#scrollTo=efYp9q7lSjpO&line=1&uniqifier=1) \\
# >>>>>
# >>>>> [2.3.3.2. Markdown](#scrollTo=gHiZa06_SjpR&line=1&uniqifier=1) \\
# >>>>>
# >>>>> [2.3.3.3. Ayuda desde el Notebook](#scrollTo=Wj-qvVDHSjpT&line=1&uniqifier=1) \\
# >>>>>
# >>>>> [2.3.3.4. Comandos Mágicos](#scrollTo=YZSUCyakSjpt&line=1&uniqifier=1) \\
# >>>>>
# >>>>> [2.3.3.5. Comandos Shell](#scrollTo=WSlTyLyMSjqb&line=1&uniqifier=1) \\
# >>>
# >>> [2.4. Funciones](#scrollTo=gW052A7USjqp&line=1&uniqifier=1) \\
# >>>
# >>> [2.5. Paquetes](#scrollTo=bYYUz7L-Sjq9&line=1&uniqifier=1) \\

# %% [markdown]
# # Preparación del entorno
#
# ¡Padawan! Cuando inicies sesión en Colab, prepara el entorno ejecutando el siguiente código.

# %%
if 'google.colab' in str(get_ipython()):
    # !git clone https://github.com/griu/mbdds_fc20.git /content/mbdds_fc20
    # !git -C /content/mbdds_fc20 pull
    # %cd /content/mbdds_fc20/Python
    # !python -m pip install -r requirementsColab.txt
# Out:
# Cloning into '/content/mbdds_fc20'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 724 (delta 8), reused 12 (delta 3), pack-reused 705
# Receiving objects: 100% (724/724), 12.21 MiB | 32.22 MiB/s, done.
# Resolving deltas: 100% (497/497), done.
# Already up to date.
# /content/mbdds_fc20/Python
# Requirement already satisfied: argon2-cffi==20.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 1)) (20.1.0)
# Requirement already satisfied: attrs==20.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 2)) (20.2.0)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 3)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 4)) (4.6.3)
# Requirement already satisfied: bleach==3.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 5)) (3.2.1)
# Collecting Brotli==1.0.9
#   Downloading https://files.pythonhosted.org/packages/b4/d3/7c98f05b7b9103e2f3a112ba42f269c798155b3e5404fb80bb8f823aaebe/Brotli-1.0.9-cp36-cp36m-manylinux1_x86_64.whl (357kB)
#      |████████████████████████████████| 358kB 2.8MB/s
# Requirement already satisfied: certifi==2020.6.20 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 7)) (2020.6.20)
# Requirement already satisfied: cffi==1.14.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 8)) (1.14.3)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 9)) (3.0.4)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 10)) (7.1.2)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 11)) (0.10.0)
# Collecting dash==1.17.0
#   Downloading https://files.pythonhosted.org/packages/69/91/ae029886dda55b93b60ac04377bcb2ab9209dd73244e3b5e513124cc6778/dash-1.17.0.tar.gz (75kB)
#      |████████████████████████████████| 81kB 7.2MB/s
# Collecting dash-core-components==1.13.0
#   Downloading https://files.pythonhosted.org/packages/52/48/3dd8c7bf93cff3a9dd9d360bc25c4ec0cb191acdce13375c3ff85f98e992/dash_core_components-1.13.0.tar.gz (3.5MB)
#      |████████████████████████████████| 3.5MB 13.4MB/s
# Collecting dash-html-components==1.1.1
#   Downloading https://files.pythonhosted.org/packages/02/ba/bb9427c62feb25bfbaf243894eeeb4e7c67a92b426ed0575a167100e436e/dash_html_components-1.1.1.tar.gz (188kB)
#      |████████████████████████████████| 194kB 32.4MB/s
# Collecting dash-renderer==1.8.3
#   Downloading https://files.pythonhosted.org/packages/72/fe/59a322edb128ad15205002c7b81e3f5e580f6791c4a100183289e05dbfcb/dash_renderer-1.8.3.tar.gz (1.0MB)
#      |████████████████████████████████| 1.0MB 20.1MB/s
# Collecting dash-table==4.11.0
#   Downloading https://files.pythonhosted.org/packages/bb/46/cc839f897cabea3f584cf59ce9d86a5ea3828e54eefe2537ba8b640a9707/dash_table-4.11.0.tar.gz (1.8MB)
#      |████████████████████████████████| 1.8MB 45.0MB/s
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 17)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 18)) (0.6.0)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 19)) (0.3)
# Requirement already satisfied: Flask==1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 20)) (1.1.2)
# Collecting Flask-Compress==1.7.0
#   Downloading https://files.pythonhosted.org/packages/de/eb/6bb0f8cb872167752eab8b06b67724566342de873dcfd85faaf7761944d9/Flask-Compress-1.7.0.tar.gz
# Requirement already satisfied: future==0.16.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 22)) (0.16.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 23)) (2.10)
# Requirement already satisfied: importlib-metadata==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 24)) (2.0.0)
# Requirement already satisfied: ipykernel==4.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 25)) (4.10.1)
# Requirement already satisfied: ipython==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 26)) (5.5.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 27)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 28)) (7.5.1)
# Requirement already satisfied: itsdangerous==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 29)) (1.1.0)
# Requirement already satisfied: jedi==0.17.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 30)) (0.17.2)
# Requirement already satisfied: Jinja2==2.11.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 31)) (2.11.2)
# Requirement already satisfied: jsonschema==2.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 32)) (2.6.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 33)) (1.0.0)
# Requirement already satisfied: jupyter-client==5.3.5 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 34)) (5.3.5)
# Requirement already satisfied: jupyter-console==5.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 35)) (5.2.0)
# Collecting jupyter-contrib-core==0.3.3
#   Downloading https://files.pythonhosted.org/packages/e6/8f/04a752a8b66a66e7092c035e5d87d2502ac7ec07f9fb6059059b6c0dc272/jupyter_contrib_core-0.3.3-py2.py3-none-any.whl
# Collecting jupyter-contrib-nbextensions==0.5.1
#   Downloading https://files.pythonhosted.org/packages/33/f0/6e2c00afda860f655fbf0f795f7310bdbf12122846344dfdc803fc7455d5/jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9MB)
#      |████████████████████████████████| 20.9MB 1.4MB/s
# Requirement already satisfied: jupyter-core==4.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 38)) (4.6.3)
# Collecting jupyter-highlight-selected-word==0.2.0
#   Downloading https://files.pythonhosted.org/packages/50/d7/19ab7cfd60bf268d2abbacc52d4295a40f52d74dfc0d938e4761ee5e598b/jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-latex-envs==1.4.6
#   Downloading https://files.pythonhosted.org/packages/0e/15/55805de080d5542f76920364635e96e64d3b37f678befdfe3b16aa154205/jupyter_latex_envs-1.4.6.tar.gz (861kB)
#      |████████████████████████████████| 870kB 42.5MB/s
# Collecting jupyter-nbextensions-configurator==0.4.1
#   Downloading https://files.pythonhosted.org/packages/51/a3/d72d5f2dc10c5ccf5a6f4c79f636bf071a5ce462dedd07af2f70384db6cb/jupyter_nbextensions_configurator-0.4.1.tar.gz (479kB)
#      |████████████████████████████████| 481kB 39.0MB/s
# Collecting jupytext==1.6.0
#   Downloading https://files.pythonhosted.org/packages/41/5b/2e6ccfaab97925f191f9dee689302b03321624bdeb3ea4831696b053734e/jupytext-1.6.0.tar.gz (683kB)
#      |████████████████████████████████| 686kB 42.1MB/s
# Requirement already satisfied: kiwisolver==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 43)) (1.2.0)
# Requirement already satisfied: lxml==4.2.6 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 44)) (4.2.6)
# Requirement already satisfied: MarkupSafe==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 45)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 46)) (3.2.2)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 47)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 48)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.8 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 49)) (5.0.8)
# Requirement already satisfied: notebook==5.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 50)) (5.3.1)
# Requirement already satisfied: numpy==1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 51)) (1.18.5)
# Requirement already satisfied: oauthlib==3.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 52)) (3.1.0)
# Requirement already satisfied: packaging==20.4 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 53)) (20.4)
# Requirement already satisfied: pandas==1.1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 54)) (1.1.3)
# Requirement already satisfied: pandocfilters==1.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 55)) (1.4.2)
# Requirement already satisfied: parso==0.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 56)) (0.7.1)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 57)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 58)) (0.7.5)
# Requirement already satisfied: Pillow==7.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 59)) (7.0.0)
# Requirement already satisfied: plotly==4.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 60)) (4.4.1)
# Requirement already satisfied: prometheus-client==0.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 61)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==1.0.18 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 62)) (1.0.18)
# Requirement already satisfied: ptyprocess==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 63)) (0.6.0)
# Requirement already satisfied: pycparser==2.20 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 64)) (2.20)
# Requirement already satisfied: Pygments==2.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 65)) (2.6.1)
# Requirement already satisfied: pymongo==3.11.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 66)) (3.11.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 67)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.17.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 68)) (0.17.3)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 69)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 70)) (2.8.1)
# Requirement already satisfied: pytz==2018.9 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 71)) (2018.9)
# Requirement already satisfied: PyYAML==3.13 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 72)) (3.13)
# Requirement already satisfied: pyzmq==19.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 73)) (19.0.2)
# Requirement already satisfied: qtconsole==4.7.7 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 74)) (4.7.7)
# Requirement already satisfied: QtPy==1.9.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 75)) (1.9.0)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 76)) (2.23.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 77)) (1.3.0)
# Requirement already satisfied: retrying==1.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 78)) (1.3.3)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 79)) (1.4.1)
# Requirement already satisfied: seaborn==0.11.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 80)) (0.11.0)
# Collecting selenium==3.141.0
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 41.8MB/s
# Requirement already satisfied: Send2Trash==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 82)) (1.5.0)
# Requirement already satisfied: simplegeneric==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 83)) (0.8.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 84)) (1.15.0)
# Collecting soupsieve==2.0.1
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Requirement already satisfied: terminado==0.9.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 86)) (0.9.1)
# Requirement already satisfied: testpath==0.4.4 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 87)) (0.4.4)
# Requirement already satisfied: toml==0.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 88)) (0.10.1)
# Requirement already satisfied: tornado==5.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 89)) (5.1.1)
# Requirement already satisfied: traitlets==4.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 90)) (4.3.3)
# Requirement already satisfied: tweepy==3.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 91)) (3.6.0)
# Collecting ujson==4.0.1
#   Downloading https://files.pythonhosted.org/packages/f1/84/e039c6ffc6603f2dfe966972d345d4f650a4ffd74b18c852ece645de12ac/ujson-4.0.1-cp36-cp36m-manylinux1_x86_64.whl (179kB)
#      |████████████████████████████████| 184kB 50.4MB/s
# Requirement already satisfied: urllib3==1.24.3 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 93)) (1.24.3)
# Requirement already satisfied: wcwidth==0.2.5 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 94)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 95)) (0.5.1)
# Requirement already satisfied: Werkzeug==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 96)) (1.0.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 97)) (3.5.1)
# Requirement already satisfied: zipp==3.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirementsColab.txt (line 98)) (3.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython==5.5.0->-r requirementsColab.txt (line 26)) (50.3.2)
# Collecting markdown-it-py~=0.5.2
#   Downloading https://files.pythonhosted.org/packages/61/2e/fc18b786ee97cf6b5e3c95fb7428b428641e28af44ee07c5d3d6f7e82220/markdown_it_py-0.5.6-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 43.4MB/s
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table, Flask-Compress, jupyter-latex-envs, jupyter-nbextensions-configurator, jupytext
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.17.0-cp36-none-any.whl size=83728 sha256=da30971cd28da00f271cc1ecf6bf410f08a9b0a7e5eb15ba724978ea15dc08df
#   Stored in directory: /root/.cache/pip/wheels/e0/32/13/8a569b638a79cf80a4a721f56040d91198adec28e3bc8123fc
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.13.0-cp36-none-any.whl size=3513142 sha256=d82bc6ed0520f265da8e79bbb556fc67f891c33a1840f3861a1e4c532e11be97
#   Stored in directory: /root/.cache/pip/wheels/44/d9/90/177214625a5b5f6440b24ea807550e07fbf439a495eee4dd36
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.1-cp36-none-any.whl size=427894 sha256=54ca54895fa098966c4d6f10614afac1dac38e0c47dc321678211af4c4bd3295
#   Stored in directory: /root/.cache/pip/wheels/8d/01/46/78e4de185a8a4a2da8ba31da16c52170f036d4cebeeb6e07a2
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.8.3-cp36-none-any.whl size=1013944 sha256=14bb20393e9e2ced6c2c1bdd2349c7abfb277e7e9ee1004e9b107db600223c52
#   Stored in directory: /root/.cache/pip/wheels/cf/2b/5f/0928a6d1b7ebf280f21a2e925f36d662e6ba83e00b82c6b6bf
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.11.0-cp36-none-any.whl size=1839767 sha256=1a229de1a34853951e4f295f7f035d1f6088c78d754322b8b27a983af3da2cb2
#   Stored in directory: /root/.cache/pip/wheels/ca/37/90/bd45dcc5d6acbe6ac53f753a8f1732ecf5270017372e389cd8
#   Building wheel for Flask-Compress (setup.py) ... done
#   Created wheel for Flask-Compress: filename=Flask_Compress-1.7.0-cp36-none-any.whl size=6833 sha256=e8df68c5485a6aeea900384bc9a405fb0e8d8dc7490aad511ccd04f8e701dd5c
#   Stored in directory: /root/.cache/pip/wheels/1d/b7/18/2b88ed33c5ef53868d1bfb0d3f2f351ae0143414734415bd06
#   Building wheel for jupyter-latex-envs (setup.py) ... done
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963395 sha256=44f440fade19ea0d0667e2e867c1e03692035ad5288d4f8e444bbfc783fba555
#   Stored in directory: /root/.cache/pip/wheels/0d/71/2a/164491997299b9f2479a251e254323fe35d946779e18f27956
#   Building wheel for jupyter-nbextensions-configurator (setup.py) ... done
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465825 sha256=680150aa7c1ffb54f133694c0f2fec4f7cc18ffbb83a46c52a996413ba866f51
#   Stored in directory: /root/.cache/pip/wheels/15/df/fe/2a74fe34709e7fdc5ae153a768675d9fda93cc7d5133ed1fb0
#   Building wheel for jupytext (setup.py) ... done
#   Created wheel for jupytext: filename=jupytext-1.6.0-cp36-none-any.whl size=284372 sha256=3864065a69a1db5cc0696dbca19c57dcc293fcc4d26a5af7b004eaf38b79da56
#   Stored in directory: /root/.cache/pip/wheels/23/13/4c/e6bfca130c64ffce096b9de410bcfcc669d2b70eb584b2caff
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table Flask-Compress jupyter-latex-envs jupyter-nbextensions-configurator jupytext
# Installing collected packages: Brotli, Flask-Compress, dash-renderer, dash-core-components, dash-html-components, dash-table, dash, jupyter-contrib-core, jupyter-latex-envs, jupyter-highlight-selected-word, jupyter-nbextensions-configurator, jupyter-contrib-nbextensions, markdown-it-py, jupytext, selenium, soupsieve, ujson
# Successfully installed Brotli-1.0.9 Flask-Compress-1.7.0 dash-1.17.0 dash-core-components-1.13.0 dash-html-components-1.1.1 dash-renderer-1.8.3 dash-table-4.11.0 jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.1 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.6 jupyter-nbextensions-configurator-0.4.1 jupytext-1.6.0 markdown-it-py-0.5.6 selenium-3.141.0 soupsieve-2.0.1 ujson-4.0.1

# %% [markdown]
# # 2 - Elementos Básicos de Python

# %% [markdown]
# Aunque se presuponen unos conocimientos iniciales de Python, a continuación, hacemos un repaso de Python, Anaconda y notebooks de Jupyter-Colab. El objetivo es reforzar aquellos elementos más orientados al análisis de datos.

# %% [markdown]
# #### 2.1 Interfaz de Usuario

# %% [markdown]
# Python se puede ejecutar de forma interactiva desde consola de texto. Para abrir la consola, ejecutaremos el comando Python desde un terminal Windows o Linux. El temario utiliza notebooks ejecutados desde Jupyter y/o Colab.
#
# Prueba a ejecutar la siguiente línea, directamente, en este notebook.

# %%
6 / (4 - 1.5)
# Out:
# 2.4

# %% [markdown]
# > **Recuerda**: Para editar una celda del notebook, pulsa `Enter`. Para ejecutarla, pulsa  `Ctrl+Enter` (sólo ejecutar), o bien, `Mayús+Enter` (para ejecutar y avanzar celda).

# %% [markdown]
# #### 2.2 Ficheros *.py
#
# Una forma habitual de programar en Python es mediante ficheros de texto con extensión `.py`. Existen múltiples entornos para estos ficheros: Spyder (parecido a RStudio), PyCharm, Visual Studio Code o cualquier editor de texto como Notepad++.
#
# Este tipo de ficheros se utilizan habitualmente para generar librerías de funciones y ejecutar desarrollo productivo de aplicaciones en Python.

# %% [markdown]
# #### 2.3. Notebooks Jupyter (*.ipynb)
#
# Los notebooks, como éste que estás leyendo, son la solución de la comunidad de SciPy para la programación interactiva. El proyecto nació con el nombre [IPython](https://ipython.org) (o Python interactivo) y, actualmente, se orquestra en el paraguas de la plataforma [Jupyter](https://jupyter.org/).
#
# Jupyter permite ejecutar, de forma interactiva, docenas de lenguajes como Python, R, etc.
#
# Los notebooks, al igual que Rmardown, permiten combinar texto en formato Markdown (lenguaje de marcas ligero), con código con resultados en forma de texto o gráficos. Esta forma de funcionar resulta óptima para el análisis de datos y la formación.
#
# Su uso se ha extendido de la mano del proyecto [Anaconda](https://www.anaconda.com/), la mayor plataforma de gestión de librerías open source enfocadas a la computación científica.
#
# Para iniciar el entorno Jupyter, sigue la guía del ***Anexo: README de Python*** apartado "PREPARACIÓN ENTORNO LOCAL-JUPYTER (OPCIONAL)".

# %% [markdown]
# ##### 2.3.1. Colaboratory o Colab
#
# Actualmente, la comunidad Python cuenta con la plataforma [Colaboratory o Colab](https://colab.research.google.com) que es un entorno libre para ejecutar notebooks Jupyter y almacenarlos en Google Drive.
#
# Este entorno sólo permite abrir ficheros .ipynb (no .py), pero facilita en gran medida su uso para desarrollar formación.
#
# En la parte superior de los notebooks, encontrarás un script que inicializa el entorno Colab con las versiones de los paquetes de Python correctas y descarga el repositorio Github con el material del curso.

# %% [markdown]
# ##### 2.3.2. Actividad Guiada 2.1.
#
# Crea tu primer notebook.
#
# En Jupyter/Colab, accede al menú `File > New Notebook`.
#
# > En Jupyter, selecciona el Kernel `mbdds_rpy20` que has creado como se indica en el ***Anexo: README de Python***.
#
# Inserta el siguiente código Python y ejecútalo:
#
# ```
# print("Hello Wold!")
# ```
#
# Guarda el documento con el nombre `21_actividad`.

# %% [markdown]
# ##### 2.3.3. Editar Notebooks Jupyter
#
# Un notebook está compuesto por un conjunto de casillas que pueden ser de distinto tipo:
#
# - *Code*: código Python que se puede ejecutar interactivamente y puede tener un salida o output.
# - *Markdown*: inserta texto con este formato. No tiene output.
#
# Una casilla, puede tener dos modos:
#
# - Edición: pulsa `Enter` o haz doble clic. Puedes modificar su contenido Python o Markdown.
# - Visión: pulsa la tecla `Esc` o haz clic en la barra izquierda (en Jupyter). Selecciona una o varias casillas con el ratón o con las teclas `Mayús + Cursos`.
#
# Para mostrar una casilla Markdown en formato impresión (sin marcas), ejecútala del mismo modo que si fuera código:
#   - Sólo ejecutar: `Ctrl+Enter`.
#   - Ejecutar y avanzar casilla: botón `Run`, o bien, `Mayús+Enter`.

# %% [markdown]
# ###### 2.3.3.1. Atajos de Teclado
#
# Puedes gestionar las celdas desde el teclado, en el modo de Visión (**tecla`Esc`**):
#
# - Cambiar tipo celda:
#   - Modo Markdown: tecla `M`, `Ctr+M+M` (Colab).
#   - Modo Code: tecla `Y`, `Ctr+M+Y` (Colab).
# - Insertar celdas:
#   - Antes: tecla `A`, `Ctr+M+A` (Colab).
#   - Después: tecla `B`, `Ctr+M+B` (Colab).
# - Copiar, pegar, desplazar arriba, abajo, etc.

# %% [markdown]
# ######  2.3.3.2. Markdown
#
# - **Parágrafo de texto**: deja  una línea en blanco (`Enter`) antes y después de un parágrafo de texto.
# - **Encabezados**: utiliza # seguido de espacio en blanco para los títulos de las secciones:
# ```
# # TITULO NIVEL 1
# ## TITULO NIVEL 2
# ...
# ```
# Deja también una línea en blanco (`Enter`) antes y después del título.
# - **Emphasis**: negrita con `**string**`. Cursiva con `*string*`.
# - **Código látex**:  ```$x^2$```. $x^2$.
# - **Fuente ancho fijo**:  \`texto\` (usa tilde abierta o con orientación izquierda).
# - **Bloque de código (sin que se ejecute)**: comentario o código (nueva línea), se escriben tres tildes abiertas. Ejemplo:
# \`\`\`
# ```
# Soy codigo1
# Soy código2
# ```
# \`\`\`
# - **Línea en blanco**: usa una línea nueva con dos espacios o `<br>`.
# - **Lista de puntos**: al inicio de línea, usa guion `-` seguido de espacio y texto. Para una sublista de puntos, pon tres espacios o tabulado y guión. Puedes usar también asterisco.
# - **Lista numerada**: Al inicio, pon `1. `, seguido de espacio y texto. No es necesario cambiar el `1.` en cada nueva línea.
# - **Link externo**: `[texto enlace](http://url)`
# - **Link interno**: crea un ID con html `<a id="seccion_ID"></a>` antes de la sección. Ahora, para enlazar con la sección, utiliza `[titulo sección](#seccion_ID)`.
# - **Imagen**: arrastrar y soltar en la celda markdown. También con `![texto alternativo](url imagen o ruta del a imagen)`, o también, ` <img src="url imagen o ruta del a imagen" alt="texto alternativo" title="texto descriptivo" />` .
# - **Sangrado (Indented)**: al incio de línea, usa símbolo `> ` seguido de espacio y texto. Ejemplo:
#
# > Texto sangrado
#
# - **Línea horizontal**: tres asteriscos al inicio de línea, `***` .
# - **Colores**: usa `<font color=blue|red|green|pink|yellow>Texto</font>` .

# %% [markdown]
# ######   2.3.3.3. Ayuda desde el Notebook
#
# En Python, se pide ayuda de un comando con:

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# En Jupyter, ejecuta `?comando` para que se abra un menú contextual de ayuda.

# %%
# ?len

# %% [markdown]
# El tabulador te ayuda a autocompletar código, ver opciones, parámetros...

# %% [markdown]
# ######   2.3.3.4. Comandos Mágicos
#
# Los comandos mágicos aumentan las capacidades interactivas de los notebooks. Son de uso común:
#
# Ejecuta script .py

# %%
# %run holaMundo.py
# Out:
# Hello World!

# %% [markdown]
# Historial de comandos ejecutados.

# %%
# vemos los primerso 3:
# %history 1-3
# Out:
# if 'google.colab' in str(get_ipython()):
#     !git clone https://github.com/griu/mbdds_fc20.git /content/mbdds_fc20
#     !git -C /content/mbdds_fc20 pull
#     %cd /content/mbdds_fc20/Python
#     !python -m pip install -r requirementsColab.txt
# 6 / (4 - 1.5)
# help(len)

# %% [markdown]
# Cambiar de directorio de trabajo.
#
# ```
# %cd nueva_ruta
# ```

# %% [markdown]
# Tiempo de ejecución de una línea:

# %%
# %time L = [n ** 2 for n in range(1000)]
# Out:
# Wall time: 0 ns

# %% [markdown]
# De toda una celda:

# %%
# %%time
L1 = [n ** 2 for n in range(1000)]
L2 = [n ** 2 for n in range(1000)]
L3 = [n ** 2 for n in range(1000)]
# Out:
# Wall time: 2 ms

# %% [markdown]
# ######   2.3.3.5. Comandos Shell

# %% [markdown]
# Los comandos de sistema se pueden ejecutar con `!comando`:

# %%
# !dir
# Out:
# holaMundo.py			       modulo1_tema4_Py_60_anexo.ipynb
# modulo1_tema4_Py_00_indice.ipynb       modulo1_tema4_Py_Ejercicios.ipynb
# modulo1_tema4_Py_10_elem_bas.ipynb     modulo1_tema4_Py.ipynb
# modulo1_tema4_Py_20_matplotlib.ipynb   ppt
# modulo1_tema4_Py_30_colec_obj.ipynb    README.md
# modulo1_tema4_Py_31_numpy.ipynb        requirementsColab.txt
# modulo1_tema4_Py_32_pandas.ipynb       Rmd
# modulo1_tema4_Py_40_contr_flujo.ipynb  www
# modulo1_tema4_Py_50_gest_dat.ipynb

# %% [markdown]
# #### 2.4. Funciones
#
# Para definir la función valor absoluto:

# %%
def valor_absoluto(num):
    """devuelve el valor absoluto"""

    if num >= 0:
        return num
    else:
        return -num

# %% [markdown]
# - Se inicia la definición con `def`, seguido del nombre de la función.
# - A continuación, los parámetros entre paréntesis y `:`
#   - Admite definir valores por defecto.
# - El texto sirve como ayuda cuando se llama a ?valor_absoluto.
# - El cuerpo del código con sangrado.
# - Puede devolver un objeto añadiendo `return objecto`.
# - Si quieres devolver valores por pantalla hay que usar print.
#
# Para llamar a la función:

# %%
valor_absoluto(-6)
# Out:
# 6

# %% [markdown]
# #### 2.5. Paquetes
#
# El indexador de paquetes de Python es **PyPI**. igual que **CRAN** en R. Actualmente, indexa más de 235.000 librearías.
#
# Para instalarlos hay distintos métodos. El más general es mediante `pip` desde Shell:
#
# ```
# pip install nombre_paquete
# ```
#
# > **Sabías que**: Anaconda tiene su propio gestor de paquetes llamado `conda`. Funciona de forma similar a `pip`. Además, `conda`, aporta la capacidad de gestionar *Environments*, que a su vez, permiten fijar un conjunto de versiones de paquetes de Python. Los *Environments* facilitan reproducir en otras máquinas todo el entorno de ejecución y la replicabilidad de los desarrollos. Revisa un ejemplo en [Anexo: README de Python](modulo1_tema4_Py_60_anexo.ipynb).
#
# Desde Jupyter/Colab también se pueden instalar paquetes con `!pip` y `!conda` (fíjate que ahora llevan `!` delante).
#
# ```
# !pip install nombre_paquete
# ```
#
# Una vez instalados, en cada nueva sesión de Jupyter, hay que importarlos para que sean accesibles:
#
# ```
# import nombre_paquete
# ```
